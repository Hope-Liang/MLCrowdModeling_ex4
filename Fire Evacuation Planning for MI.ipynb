# %%
import numpy as np
import math
import matplotlib.pyplot as plt

X=np.load('FireEvac_train_set.npy')
Y=np.load('FireEvac_test_set.npy')

# %%
plt.scatter(X[:,0],X[:,1])

# %%
plt.scatter(Y[:,0],Y[:,1])
